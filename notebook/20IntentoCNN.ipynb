# %%
import tensorflow as tf
from tensorflow.keras import backend
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt

# %%
train_dir = './train'
test_dir = './test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=64,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=64,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True
)
# Out:
# Found 11879 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    #tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       294,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 535,938 (2.04 MB)
#  Trainable params: 535,938 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# liberar memoria para amenizar el proceso de entrenamiento
# Liberar la memoria de la GPU
backend.clear_session()

# %%
#steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = test_generator.samples // test_generator.batch_size

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=63,
    epochs=15,
    batch_size=64,  # Ajuste el tamaño del batch
    validation_data=test_generator,
    validation_steps=validation_steps,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.5270 - loss: 0.6879 - val_accuracy: 0.4995 - val_loss: 0.6841
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.5552 - loss: 0.6747 - val_accuracy: 0.5625 - val_loss: 0.6545
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 103s 2s/step - accuracy: 0.6408 - loss: 0.6403 - val_accuracy: 0.8090 - val_loss: 0.6273
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.6852 - loss: 0.6078 - val_accuracy: 0.6875 - val_loss: 0.5854
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.7191 - loss: 0.5650 - val_accuracy: 0.6870 - val_loss: 0.5567
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.7192 - loss: 0.5666 - val_accuracy: 0.7500 - val_loss: 0.5491
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7340 - loss: 0.5532 - val_accuracy: 0.7440 - val_loss: 0.5148
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.7518 - loss: 0.5226 - val_accuracy: 0.8125 - val_loss: 0.4228
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.7629 - loss: 0.5056 - val_accuracy: 0.5958 - val_loss: 0.7259
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7691 - loss: 0.4990 - val_accuracy: 0.8125 - val_loss: 0.4965
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7853 - loss: 0.4750 - val_accuracy: 0.8090 - val_loss: 0.4655
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.7790 - loss: 0.4828 - val_accuracy: 0.6875 - val_loss: 0.5533
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.7835 - loss: 0.4645 - val_accuracy: 0.8049 - val_loss: 0.4756

# %%
# Guardar el modelo completo
model.save('models/20_cnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Graficar la pérdida
plt.figure(figsize=(4, 3))
plt.plot(history.history['loss'], label='Pérdida de Entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de Validación')
plt.title('Evolución de la Pérdida')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# Graficar la exactitud
plt.figure(figsize=(4, 3))
plt.plot(history.history['accuracy'], label='Exactitud de Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Exactitud de Validación')
plt.title('Evolución de la Exactitud')
plt.xlabel('Época')
plt.ylabel('Exactitud')
plt.legend()
plt.show()

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Gráficas</title>
</head>
<body>
    <p>Esto no es exactamente lo que buscamos, ya que la gráfica que estamos buscando se parece más a esta:</p>
    <img src="img/perdida.png" alt="Gráfica Correcta" width="250">
    <img src="img/bien_entrenado.png" alt="Gráfica Correcta" width="250">
</body>
</html>
"""

# Mostrar el contenido HTML en el notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Gráficas</title>
# </head>
# <body>
#     <p>Esto no es exactamente lo que buscamos, ya que la gráfica que estamos buscando se parece más a esta:</p>
#     <img src="img/perdida.png" alt="Gráfica Correcta" width="250">
#     <img src="img/bien_entrenado.png" alt="Gráfica Correcta" width="250">
# </body>
# </html>

# %% [markdown]
# Crearemos un nuevo modelo con menos capas para ver que resultado obtenemos

# %%
model = tf.keras.models.load_model('models/14_cnn.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Mostrar precision y perdida del modelo
loss, acc = model.evaluate(test_generator)
print(f'Pérdida: {loss}')
print(f'Exactitud: {acc}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 102ms/step - accuracy: 0.8256 - loss: 0.4419
# Pérdida: 0.4374816417694092
# Exactitud: 0.824999988079071
