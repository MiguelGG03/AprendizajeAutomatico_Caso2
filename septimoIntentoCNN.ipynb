# %%
import tensorflow as tf
from tensorflow.keras import backend
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

# %%
train_dir = './train'
test_dir = './test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True
)
# Out:
# Found 11879 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
# Out:
# c:\Users\mglez\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 127008)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │     4,064,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,065,746 (15.51 MB)
#  Trainable params: 4,065,746 (15.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# liberar memoria para amenizar el proceso de entrenamiento
# Liberar la memoria de la GPU
backend.clear_session()
# Out:
# WARNING:tensorflow:From c:\Users\mglez\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# Ajustar el modelo
history = model.fit(
    train_generator,
    steps_per_epoch=60,
    epochs=20,
    validation_data=test_generator,
    validation_steps=50
)
# Out:
# c:\Users\mglez\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.5549 - loss: 0.6904
# c:\Users\mglez\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 43s 627ms/step - accuracy: 0.5558 - loss: 0.6897 - val_accuracy: 0.5350 - val_loss: 0.7119
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 363ms/step - accuracy: 0.6847 - loss: 0.5878 - val_accuracy: 0.6275 - val_loss: 0.5944
# Epoch 3/20
# c:\Users\mglez\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 474ms/step - accuracy: 0.7709 - loss: 0.4889 - val_accuracy: 0.6612 - val_loss: 0.5532
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 325ms/step - accuracy: 0.7647 - loss: 0.4676 - val_accuracy: 0.7675 - val_loss: 0.4750
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 457ms/step - accuracy: 0.7576 - loss: 0.4582 - val_accuracy: 0.7837 - val_loss: 0.4748
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 295ms/step - accuracy: 0.8010 - loss: 0.4330 - val_accuracy: 0.7275 - val_loss: 0.4997
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.7979 - loss: 0.4204 - val_accuracy: 0.7825 - val_loss: 0.4472
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 337ms/step - accuracy: 0.8083 - loss: 0.4123 - val_accuracy: 0.6875 - val_loss: 0.5209
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 30s 499ms/step - accuracy: 0.8031 - loss: 0.4225 - val_accuracy: 0.6500 - val_loss: 0.6236
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 334ms/step - accuracy: 0.8007 - loss: 0.4361 - val_accuracy: 0.8100 - val_loss: 0.4535
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 443ms/step - accuracy: 0.8222 - loss: 0.3716 - val_accuracy: 0.7887 - val_loss: 0.4372
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 284ms/step - accuracy: 0.8178 - loss: 0.3937 - val_accuracy: 0.8400 - val_loss: 0.4311
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 458ms/step - accuracy: 0.8049 - loss: 0.4167 - val_accuracy: 0.7600 - val_loss: 0.4584
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8034 - loss: 0.4119 - val_accuracy: 0.7300 - val_loss: 0.4775
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 456ms/step - accuracy: 0.8284 - loss: 0.3700 - val_accuracy: 0.7319 - val_loss: 0.4867
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 327ms/step - accuracy: 0.8313 - loss: 0.3648 - val_accuracy: 0.7275 - val_loss: 0.5093
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 457ms/step - accuracy: 0.8172 - loss: 0.3837 - val_accuracy: 0.7437 - val_loss: 0.4807
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 326ms/step - accuracy: 0.8217 - loss: 0.3751 - val_accuracy: 0.8125 - val_loss: 0.4490
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 471ms/step - accuracy: 0.8090 - loss: 0.4084 - val_accuracy: 0.7994 - val_loss: 0.4069
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 294ms/step - accuracy: 0.8299 - loss: 0.3661 - val_accuracy: 0.8725 - val_loss: 0.3622

# %%
# Guardar el modelo completo
model.save('models/septimo_cnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Graficar la pérdida
plt.plot(history.history['loss'], label='Pérdida de Entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de Validación')
plt.title('Evolución de la Pérdida')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# Graficar la exactitud
plt.plot(history.history['accuracy'], label='Exactitud de Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Exactitud de Validación')
plt.title('Evolución de la Exactitud')
plt.xlabel('Época')
plt.ylabel('Exactitud')
plt.legend()
plt.show()

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Gráficas</title>
</head>
<body>
    <p>Esto no es exactamente lo que buscamos, ya que la gráfica que estamos buscando se parece más a esta:</p>
    <img src="img/perdida.png" alt="Gráfica Correcta" width="250">
    <img src="img/bien_entrenado.png" alt="Gráfica Correcta" width="250">
</body>
</html>
"""

# Mostrar el contenido HTML en el notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Gráficas</title>
# </head>
# <body>
#     <p>Esto no es exactamente lo que buscamos, ya que la gráfica que estamos buscando se parece más a esta:</p>
#     <img src="img/perdida.png" alt="Gráfica Correcta" width="250">
#     <img src="img/bien_entrenado.png" alt="Gráfica Correcta" width="250">
# </body>
# </html>

# %% [markdown]
# Crearemos un nuevo modelo con menos capas para ver que resultado obtenemos

# %%
# Mostrar precision y perdida del modelo
loss, acc = model.evaluate(test_generator)
print(f'Pérdida: {loss}')
print(f'Exactitud: {acc}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Mostrar precision y perdida del modelo
# ----> 2 loss, acc = model.evaluate(test_generator)
#       3 print(f'Pérdida: {loss}')
#       4 print(f'Exactitud: {acc}')
#
# NameError: name 'model' is not defined
